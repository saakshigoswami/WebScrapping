# %%
# 1. go to website
# 2. search for the product
# 3. locate url for each box 
# 4. locate review part
# 5 . scrap all the dat in local system

# %%
from flask_cors import CORS, cross_origin
from flask import Flask, request, jsonify, render_template 
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as ureq

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "iphone"
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone'

# %%
# urlreq open up the url
uClient= ureq(flipkart_url)
uClient

# %%
flipkartpage = uClient.read()
flipkartpage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
uClient.close()

# %%
## TO MAKE THE INFORMATION READABLE
flipkart_html = bs(flipkartpage, "html.parser")
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigboxes = flipkart_html.find_all("div", {"class": "_1AtVbE col-12-12"})
bigboxes
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,4
# ...

# %%
len(bigboxes)
# Out:
# 30

# %%
for i in bigboxes:
    print(i)
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,4i
# ...

# %%
box=bigboxes[4]
type(box)
# Out:
# bs4.element.Tag

# %%
box.div.div.div.a["href"]
# Out:
# '/apple-iphone-14-starlight-128-gb/p/itm3485a56f6e676?pid=MOBGHWFHABH3G73H&lid=LSTMOBGHWFHABH3G73HVXY5AV&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=149d0b1f-9666-448d-b1b6-7bfadeb7f877.MOBGHWFHABH3G73H.SEARCH&ppt=None&ppn=None&ssid=jwng9mzba80000001687349043298&qH=0b3f45b266a97d70'

# %%
productlink = 'https://www.flipkart.com' + box.div.div.div.a["href"]
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-14-starlight-128-gb/p/itm3485a56f6e676?pid=MOBGHWFHABH3G73H&lid=LSTMOBGHWFHABH3G73HVXY5AV&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=149d0b1f-9666-448d-b1b6-7bfadeb7f877.MOBGHWFHABH3G73H.SEARCH&ppt=None&ppn=None&ssid=jwng9mzba80000001687349043298&qH=0b3f45b266a97d70'

# %%
productpage = requests.get(productlink)
productpage
# Out:
# <Response [200]>

# %%
productpage.encoding = 'utf-8'

# %%
productpage_html = bs(productpage.text, "html.parser")
productpage_html
# Out:
# <!DOCTYPE html>
# ...

# %%
reviewbox = productpage_html.find_all('div', {'class' :"col _2wzgFH"})
reviewbox
# Out:
# [<div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Great product</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Damn such a great phone. Camera is really good, battery lasts long enough, super smooth even though its just 60 hz XDR display. Videos with action mode on are insanely stable and crisp.The night mode can take some really good shots jn low light conditions .The whole apple environment itself is so seamless. I shifted from android to iPhone and it barely took any time since I had iPad and a mac already. With a just a few clicks the phone was ready to go.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_1a1c66f39937419db8d27ab644b4f24a.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><
# ...

# %%
boxrev = reviewbox[0]
boxrev
# Out:
# <div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Great product</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Damn such a great phone. Camera is really good, battery lasts long enough, super smooth even though its just 60 hz XDR display. Videos with action mode on are insanely stable and crisp.The night mode can take some really good shots jn low light conditions .The whole apple environment itself is so seamless. I shifted from android to iPhone and it barely took any time since I had iPad and a mac already. With a just a few clicks the phone was ready to go.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_1a1c66f39937419db8d27ab644b4f24a.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><d
# ...

# %%
len(reviewbox)
# Out:
# 10

# %%
boxrev
# Out:
# <div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Great product</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Damn such a great phone. Camera is really good, battery lasts long enough, super smooth even though its just 60 hz XDR display. Videos with action mode on are insanely stable and crisp.The night mode can take some really good shots jn low light conditions .The whole apple environment itself is so seamless. I shifted from android to iPhone and it barely took any time since I had iPad and a mac already. With a just a few clicks the phone was ready to go.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_1a1c66f39937419db8d27ab644b4f24a.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><d
# ...

# %%
# class="t-ZTKy" = comment
# <p class="_2sc7ZR _2V5EHH" = name
# class="_3LWZlK _1BLPMq" = rating
# <p class="_2-N8zT"> = review heading

# %%
reviewbox[0].find_all('div',{'class': "t-ZTKy"})[0].text
# Out:
# 'Damn such a great phone. Camera is really good, battery lasts long enough, super smooth even though its just 60 hz XDR display. Videos with action mode on are insanely stable and crisp.The night mode can take some really good shots jn low light conditions .The whole apple environment itself is so seamless. I shifted from android to iPhone and it barely took any time since I had iPad and a mac already. With a just a few clicks the phone was ready to go.READ MORE'

# %%
for i in range(len(reviewbox)) :
    print(reviewbox[i].find_all('div',{'class': "t-ZTKy"})[0].text)
# Out:
# Damn such a great phone. Camera is really good, battery lasts long enough, super smooth even though its just 60 hz XDR display. Videos with action mode on are insanely stable and crisp.The night mode can take some really good shots jn low light conditions .The whole apple environment itself is so seamless. I shifted from android to iPhone and it barely took any time since I had iPad and a mac already. With a just a few clicks the phone was ready to go.READ MORE
# Just awesome!!I switch to iPhone 14 from iPhone 12. The powerful chipset gives you smooth performance. No lags, no fancy UI, just delivers the best of it. Camera is best. Battery giving a full day. Speaker sounds wide and clear. Must buy!!READ MORE
# ...

# %%
name = productpage_html.find_all('p', {'class' : '_2sc7ZR _2V5EHH'})
name
# Out:
# [<p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>,
#  <p class="_2sc7ZR _2V5EHH">Feecon Behera</p>,
#  <p class="_2sc7ZR _2V5EHH">Kunal Dhamija</p>,
#  <p class="_2sc7ZR _2V5EHH">Manish Choudhary</p>,
#  <p class="_2sc7ZR _2V5EHH">Ashutosh Kumar</p>,
#  <p class="_2sc7ZR _2V5EHH">afzal khan</p>,
#  <p class="_2sc7ZR _2V5EHH">Sunder Singh </p>,
#  <p class="_2sc7ZR _2V5EHH">sagar dimble</p>,
#  <p class="_2sc7ZR _2V5EHH">Vipul Rai</p>,
#  <p class="_2sc7ZR _2V5EHH">Debasish  Kakati</p>]

# %%
reviewbox[0].find_all('p', {'class' : '_2sc7ZR _2V5EHH'})[0].text
# Out:
# 'Flipkart Customer'

# %%
for i in reviewbox:
     print(i.find_all('p', {'class' : '_2sc7ZR _2V5EHH'})[0].text)

# %%
for i in range(len(reviewbox)):
    print(reviewbox[i].find_all('div', {'class' : '_3LWZlK _1BLPMq'})[0].text)
# Out:
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 4
# 5
# 5

# %%
reviewbox[0].find_all('p',{'class' : "_2-N8zT"})[0].text
# Out:
# 'Great product'

# %%
for i in range(len(reviewbox)):
    print(reviewbox[i].find_all('p',{'class' : "_2-N8zT"})[0].text)
# Out:
# Great product
# Must buy!
# Classy product
# Perfect product!
# Classy product
# Fabulous!
# Highly recommended
# Nice product
# Awesome
# Just wow!

# %%
for i in reviewbox:
    print(i.find_all('p', {'class' : '_2sc7ZR _2V5EHH'})[0].text)
    print(i.find_all('div', {'class' : '_3LWZlK _1BLPMq'})[0].text)
    print(i.find_all('p',{'class' : "_2-N8zT"})[0].text)
    print(i.find_all('div',{'class': "t-ZTKy"})[0].text)
    print("\n")
# Out:
# Flipkart Customer
# 5
# Great product
# Damn such a great phone. Camera is really good, battery lasts long enough, super smooth even though its just 60 hz XDR display. Videos with action mode on are insanely stable and crisp.The night mode can take some really good shots jn low light conditions .The whole apple environment itself is so seamless. I shifted from android to iPhone and it barely took any time since I had iPad and a mac already. With a just a few clicks the phone was ready to go.READ MORE
#
#
# Feecon Behera
# 5
# Must buy!
# Just awesome!!I switch to iPhone 14 from iPhone 12. The powerful chipset gives you smooth performance. No lags, no fancy UI, just delivers the best of it. Camera is best. Battery giving a full day. Speaker sounds wide and clear. Must buy!!READ MORE
#
#
# Kunal Dhamija
# 5
# Classy product
# ...

# %%
            finame =  "Search.csv"
            fw=open(finame,"w")
            headers = "Product, Customer Name, Rating, Heading, Comment \n"
            fw.write(headers)
# Out:
# 50
